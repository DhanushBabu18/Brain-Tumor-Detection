# %%
# Detection of Brain Tumor via Deep Learning

# %%
import numpy as np 
import pandas as pd
import os
for dirname, _, filenames in os.walk('C:/Users/dhanu/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:/Users/dhanu/input\Testing\glioma_tumor\image(1).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(10).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(100).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(11).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(12).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(13).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(14).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(15).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(16).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(17).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(18).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(19).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(2).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(20).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(21).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(22).jpg
# C:/Users/dhanu/input\Testing\glioma_tumor\image(23).jpg
# ...

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout
from sklearn.metrics import accuracy_score

# %%
import ipywidgets as widgets
import io
from PIL import Image
import tqdm
from sklearn.model_selection import train_test_split
import cv2
from sklearn.utils import shuffle
import tensorflow as tf

# %%
X_train = []
Y_train = []
image_size = 150
labels = ['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']
for i in labels:
    folderPath = os.path.join('C:/Users/dhanu/input/Training',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('C:/Users/dhanu/input/Testing',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
X_train,Y_train = shuffle(X_train,Y_train,random_state=101)
X_train.shape
# Out:
# (3264, 150, 150, 3)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,Y_train,test_size=0.1,random_state=101)

# %%
X_train.shape,X_test

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train=y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test=y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
##Model Training

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),activation = 'relu',input_shape=(150,150,3)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Dropout(0.3))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(512,activation = 'relu'))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(4,activation='softmax'))
# Out:
# C:\Users\dhanu\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 146, 146, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 73, 73, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 73, 73, 64)          │               0 │
# ...

# %%
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %% [markdown]
# ##Accuracy

# %%
import matplotlib.pyplot as plt
import seaborn as sns

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(len(acc))
fig = plt.figure(figsize=(11,7))
plt.plot(epochs,acc,'r',label="Training Accuracy")
plt.plot(epochs,val_acc,'b',label="Validation Accuracy")
plt.legend(loc='upper left')
plt.show()

# %%
history = model.fit(X_train,y_train,epochs=20,validation_split=0.1)
# Out:
# Epoch 1/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 74s 803ms/step - accuracy: 0.2884 - loss: 3.1578 - val_accuracy: 0.2959 - val_loss: 1.3574
# Epoch 2/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 67s 808ms/step - accuracy: 0.4348 - loss: 1.2322 - val_accuracy: 0.6054 - val_loss: 0.8824
# Epoch 3/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 66s 791ms/step - accuracy: 0.5913 - loss: 0.9571 - val_accuracy: 0.6088 - val_loss: 0.8791
# Epoch 4/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 64s 777ms/step - accuracy: 0.6625 - loss: 0.7943 - val_accuracy: 0.6939 - val_loss: 0.7718
# Epoch 5/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 66s 792ms/step - accuracy: 0.6928 - loss: 0.7423 - val_accuracy: 0.6429 - val_loss: 0.7609
# Epoch 6/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 66s 799ms/step - accuracy: 0.7429 - loss: 0.6054 - val_accuracy: 0.7517 - val_loss: 0.6507
# Epoch 7/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 66s 796ms/step - accuracy: 0.7695 - loss: 0.5823 - val_accuracy: 0.7551 - val_loss: 0.5498
# Epoch 8/20
# ...

# %% [markdown]
# ##Evaluation of the model

# %%
model.evaluate(X_test,y_test)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.8883 - loss: 0.3066
# [0.29130154848098755, 0.8990825414657593]

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(loss))
fig = plt.figure(figsize=(11,7))
plt.plot(epochs,loss,'r',label="Training loss")
plt.plot(epochs,val_loss,'b',label="Validation loss")
plt.legend(loc='upper left')
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(loss))
fig = plt.figure(figsize=(11,7))
plt.plot(epochs,loss,'r',label="Training loss")
plt.plot(epochs,val_loss,'b',label="Validation loss")
plt.legend(loc='upper left')
plt.show()

# %%
img = cv2.imread('C:/Users/dhanu/input/Training/pituitary_tumor/p (107).jpg')
img = cv2.resize(img,(150,150))
img_array = np.array(img)
img_array.shape
# Out:
# (150, 150, 3)

# %%
img_array = img_array.reshape(1,150,150,3)
img_array.shape
# Out:
# (1, 150, 150, 3)

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img('C:/Users/dhanu/input/Training/pituitary_tumor/p (107).jpg')
plt.imshow(img,interpolation='nearest')
plt.show()

# %%
a=model.predict(img_array)
indices = a.argmax()
indices
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 3
